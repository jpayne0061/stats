# %% [markdown]
# # Analysis of Salaries

# %% [markdown]
# The Notebook has added support for `raw_input` and `%debug`, as of 1.0.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
# %pylab inline

master = pd.read_csv("../data_sets/baseballdatabank-master/core/Master.csv")
salaries = pd.read_csv("../data_sets/baseballdatabank-master/core/Salaries.csv")

salary_merge = pd.merge(master, salaries, on='playerID', how='inner')
salary_height_15 = salary_merge[salary_merge['yearID'] == 2015]

weight = salary_height_15['weight']
salary = (salary_height_15['salary'])/1000000

print stats.pearsonr(salary, height)

plt.scatter(weight, salary)
plt.tick_params(labelsize=14)
plt.xlabel('Weight(lbs)', fontsize=18)
plt.ylabel('Salary(Millions)', fontsize=18)
plt.axis([150, 320, 0, 35])
plt.title('MLB Salary vs Weight', fontsize=22, y=1.025)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('weight_salary.png', dpi=100)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (1.0, 0.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
# %pylab inline

hbp = pd.read_csv("../data_sets/baseballdatabank-master/core/Pitching.csv")
salaries = pd.read_csv("../data_sets/baseballdatabank-master/core/Salaries.csv")

hbp = hbp[hbp['yearID'] == 2015]
salary = salaries[salaries['yearID'] == 2015]

salary_hbp = pd.merge(hbp, salary, on='playerID', how='inner')

print len(salary_hbp)

salary = salary_hbp['salary']
hit_by_pitcher = salary_hbp['HBP']

plt.scatter(hit_by_pitcher, salary)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 467

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-21dc79632eb1> in <module>()
#       2 a = plt.hist(weight)
#       3 b = plt.hist(salary)
# ----> 4 a.show()
#       5 b.show()
#
# AttributeError: 'tuple' object has no attribute 'show'
